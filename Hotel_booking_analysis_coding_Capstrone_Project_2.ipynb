# %% [markdown]
# <a href="https://colab.research.google.com/github/Codewith-Soumya/Hotel-Booking-Analysis/blob/main/Hotel_booking_analysis_coding_Capstrone_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Name - Hotel Booking Analysis

# %% [markdown]
# Project Type: EDA
#
# Contribution: Individual.
#
# Name: Soumyadeep Paul

# %% [markdown]
# ## Project Summary

# %% [markdown]
# In this project we have to analyse the data to get the specific factors that governs the hotel bookings.
#
# We are using libraries like
#
# 1. Pandas for data manipulation, aggregation
# 2. Matplotlib and Seaborn for visualisation and behaviour with respect to the target variable. We have to at least 5 different visualisations but I used 8 visualizations.
# 3. NumPy for computationally efficient operations.
#
# For Visualisation purpose we are using 6 plotting parts.
#
# 1. Distribution channel wise booking analysis.
# 2. Coumtry wise booking analysis
# 3. Hotel Type wise booking analysis
# 4. Month wise booking analysis
# 5. Guest wise booking analysis
# 6. Cancellation Analysis
# 7. Occupancy rates
#
# For presenting the visualizations we are improvising:
#
# 1. Bar charts
# 2. Line graphs
# 3. Heatmaps
# 4. Pie charts
# 5. Scatter plots

# %% [markdown]
# **Data Set Description**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Github Link

# %% [markdown]
# Github link: https://github.com/Codewith-Soumya/Hotel-Booking-Analysis/blob/main/Hotel_booking_analysis_coding_Capstrone_Project_2.ipynb

# %% [markdown]
# ## Problem statement

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# ## Lets Begin

# %% [markdown]
# ### Know Your Data

# %% [markdown]
# #### Import Libraries

# %%
# importing the libraries
import numpy as np # Numerical data analysis library
import pandas as pd # importing data manipulation library
import matplotlib.pyplot as plt # importing data visualization library
import seaborn as sns # imporing data visualization library

# %% [markdown]
# We are importing 4 libraries in here which includes the numpy for numerical data analysis. Pandas for data manipulation. Matplotlib.pyplot and seaborn for data visualization analysis.

# %% [markdown]
# #### Dataset loading

# %%
# importing drive and mounting it
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# In this part of the code we are mounting the drive so that our colab file can have a clear access to our dataset.

# %%
# loading the dataset
hotel_booking_data= pd.read_csv("/content/drive/MyDrive/Hotel Bookings (1).csv")
print(hotel_booking_data)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# In this section of the code we are loading the dataset in our python code.

# %% [markdown]
# #### Data first view

# %%
hotel_booking_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# Head() shows the first 5 rows of the dataset.
#
# We can input values in the head() to extract more files.

# %%
hotel_booking_data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# #### Dataset rows and columns count

# %%
hotel_booking_data.shape
# Out:
# (119390, 32)

# %% [markdown]
# Total number of rows --> 119390
# Total number of columns --> 32

# %% [markdown]
# #### Dataset information

# %%
hotel_booking_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Here, we are gathering all the importent information of the dataset that we have regarding our hotel booking analysis. This depicts the variable type, objects, memory used by the dataset and the columns and rows information.

# %% [markdown]
# #### What do we know about our dataset?

# %% [markdown]
# Our dataset is a hotel booking dataset for two types of hotels, Resort hotel and city hotel. The overall dataset consists of 119390 rows and 32 columns. We will extract the columns of the dataset.

# %% [markdown]
# Columns of the dataset include: 'hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number','arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests' 'reservation_status', 'reservation_status_date', 'month_no', 'dateInt', 'Date', 'month_year', 'total_guest'
#
#
# There are 4 columns having float datatype, 16 columns having integer datatypes and 12 columns having objects. The memory used by the dataset is 29.1+ MB

# %% [markdown]
# ### Understanding variables

# %%
hotel_booking_data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
hotel_booking_data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# #### Variable Description

# %% [markdown]
# Here we are taking the variable as "hotel_booking_data" to denote our dataset.
#
# In python, a variable is a confined space where we are storing any specific value or a dataset.

# %% [markdown]
# #### Check Unique values for each variable

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# #### Data wrangling code

# %% [markdown]
# Handling Null Values.

# %%
Total = hotel_booking_data.isnull().sum().sort_values(ascending=False)
Percentage = (hotel_booking_data.isnull().sum()/hotel_booking_data.isnull().count()*100).sort_values(ascending=False)
Missingdata = pd.concat([Total,Percentage], axis=1, keys=['Total', 'Percentage'])
Missingdata.head(10)
# Out:
#                          Total  Percentage
# company                 112593   94.306893
# agent                    16340   13.686238
# country                    488    0.408744
# children                     4    0.003350
# reserved_room_type           0    0.000000
# assigned_room_type           0    0.000000
# booking_changes              0    0.000000
# deposit_type                 0    0.000000
# hotel                        0    0.000000
# previous_cancellations       0    0.000000

# %%
hotel_booking_data = hotel_booking_data.drop(['company','agent'], axis=1)
hotel_booking_data = hotel_booking_data.dropna()
hotel_booking_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118898 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118898 non-null  object
#  1   is_canceled                     118898 non-null  int64
#  2   lead_time                       118898 non-null  int64
#  3   arrival_date_year               118898 non-null  int64
#  4   arrival_date_month              118898 non-null  object
#  5   arrival_date_week_number        118898 non-null  int64
#  6   arrival_date_day_of_month       118898 non-null  int64
#  7   stays_in_weekend_nights         118898 non-null  int64
#  8   stays_in_week_nights            118898 non-null  int64
#  9   adults                          118898 non-null  int64
#  10  children                        118898 non-null  float64
#  11  babies                          118898 non-null  int64
# ...

# %%
hotel_booking_data = hotel_booking_data.drop(hotel_booking_data[(hotel_booking_data.adults+hotel_booking_data.babies+hotel_booking_data.children)==0].index)

#lets confirm
hotel_booking_data[(hotel_booking_data.adults+hotel_booking_data.babies+hotel_booking_data.children)==0].shape
# Out:
# (0, 30)

# %% [markdown]
# Addition of required columns and processes.

# %%
# month number column
month = {'January':1,'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8, 'September':9, 'October':10, 'November':11, 'December':12}

hotel_booking_data['month_no']=0
for index,row in hotel_booking_data.iterrows():
  hotel_booking_data.loc[index,'month_no']=month[row['arrival_date_month']]

# %%
# Adding arrival date
hotel_booking_data['dateInt']=hotel_booking_data['arrival_date_year'].astype(str) + hotel_booking_data['month_no'].astype(str).str.zfill(2)+ hotel_booking_data['arrival_date_day_of_month'].astype(str).str.zfill(2)
hotel_booking_data['Date'] = pd.to_datetime(hotel_booking_data['dateInt'], format='%Y%m%d')

# %%
# Adding month year column
hotel_booking_data['month_year'] = pd.to_datetime(hotel_booking_data['Date']).dt.to_period('M')

# %%
hotel_booking_data['total_guest']=(hotel_booking_data['adults']+hotel_booking_data['children']+hotel_booking_data['babies']).astype(int)

# %% [markdown]
# #### What are the manipulations done and the insights found

# %% [markdown]
# In this data wrangling code we handled the null values and calculated the percentage of it. We are dropping the columns with highest number of missing values. Then we are deriving the info about the dataset after droping the missing values.
#
# From the output its clear that Company has a null percentage of 94%, and the agent as only 13.68%. We will drop the higher missing value column, so the company with 94% missing value will not be considered.
#
# For Country the is 488 rows with null values comparing 488 to total numbers 0.5% so we will remove those rows only, alsochildren has four missing values we will fill with mean values, rest all are fine.
#
# After removing the null values we are adding the columns of 'month', 'arrival_date' and 'month_year'.
#
# We have now 30 column with zero null values.
#
# we will check other possiblilities here one of the threat that sum of all customer i.e Adult + children + babies should be greater than zero. lets see
#
# total 170 rows are there having sum of adults, children and babies is zero will remove these rows

# %% [markdown]
# ### Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables

# %% [markdown]
# #### Chart 1: Bar Plot

# %% [markdown]
# Distribution channel wise booking analysis.

# %%
Distribution_chanel_analysis=hotel_booking_data.groupby('distribution_channel')['hotel'].count().reset_index().sort_values(by='hotel',ascending=False)
Distribution_chanel_analysis['percentage']=(Distribution_chanel_analysis['hotel']/(Distribution_chanel_analysis['hotel'].sum()))*100
Distribution_chanel_analysis.rename(columns={'hotel':'No. of booking'},inplace=True)    # Rename the column's name
Distribution_chanel_analysis
# Out:
#   distribution_channel  No. of booking  percentage
# 3                TA/TO           97612   82.214810
# 1               Direct           14450   12.170676
# 0            Corporate            6472    5.451115
# 2                  GDS             193    0.162556
# 4            Undefined               1    0.000842

# %%
Distribution_chanel_analysis.plot.bar(x='distribution_channel',y='percentage')
# Out:
# <Axes: xlabel='distribution_channel'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see the number of bookings percentage for the distribution channels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TA/TO distribution channel has the maximum percentage of bookings which is 82.2% whearas undefined distribution channel has the lowest 0.000842%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# There is nothing as such.

# %% [markdown]
# #### Chart 2: Line plot

# %% [markdown]
# Country wise booking analysis

# %%
country_wise=hotel_booking_data.groupby('country')['hotel'].count().reset_index().sort_values(by='hotel',ascending=False)
country_wise['percentage']=(country_wise['hotel']/country_wise['hotel'].sum())*100
country_wise.rename(columns={'hotel':'No. of booking'},inplace=True) # Rename columns
country_wise.head(10)  # Get top 10 countries
# Out:
#     country  No. of booking  percentage
# 135     PRT           48479   40.831986
# 59      GBR           12120   10.208207
# 56      FRA           10401    8.760360
# 51      ESP            8560    7.209757
# 43      DEU            7285    6.135874
# 81      ITA            3761    3.167745
# 76      IRL            3374    2.841790
# 15      BEL            2342    1.972576
# 25      BRA            2222    1.871505
# 123     NLD            2103    1.771276

# %%
country_wise.head(10).plot.line(x='country',y='percentage')
# Out:
# <Axes: xlabel='country'>

# %%
d1=country_wise[['country','percentage']].head(10)
d1
# Out:
#     country  percentage
# 135     PRT   40.831986
# 59      GBR   10.208207
# 56      FRA    8.760360
# 51      ESP    7.209757
# 43      DEU    6.135874
# 81      ITA    3.167745
# 76      IRL    2.841790
# 15      BEL    1.972576
# 25      BRA    1.871505
# 123     NLD    1.771276

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see the country wise trends in booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Portugal has the highest percentage of bookings which is 40.8% whearas Netherland has the least with 1.7%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Hotels in the countries like Netherlands, Brazil and Belgium should focus on the key factors that are driving their customers off and refraining them from booking.

# %% [markdown]
# #### Chart 3: Pie Chart

# %% [markdown]
# Hotel Type wise booking analysis

# %%
hotel_type_wise_booking_analysis=hotel_booking_data.groupby('hotel')['meal'].count().reset_index()
H_type = hotel_booking_data['hotel'].value_counts().tolist()
plt.pie(H_type,explode=(0,0.1,),labels=("City","Resort"),radius=2,shadow=True,autopct='%1.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the bookings according to the hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 66.7% of the booking is for the city hotel and 33.3% of the bookings are for the resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Resort hotel should see the factors that are keeping their bookings confined to 33.3%. Following the KPIs, they should make strategies that can increase their booking rate.

# %% [markdown]
# #### Chart 4: Heatmap

# %% [markdown]
# Month wise booking analysis:
#
# Through this analysis we will get the busiest month of the year for 'city hotel' and 'resort hotel'.
#
# Here we are taking the meals count in account so that we can get the total number of bookings.

# %%
# Create month_wise data for city hotel
city_hotel_data = hotel_booking_data[hotel_booking_data['hotel'] == 'City Hotel']
city_month_wise = city_hotel_data.groupby(['month_year', 'hotel'])['meal'].count().unstack()

# Create month_wise data for resort hotel
resort_hotel_data = hotel_booking_data[hotel_booking_data['hotel'] == 'Resort Hotel']
resort_month_wise = resort_hotel_data.groupby(['month_year', 'hotel'])['meal'].count().unstack()

# Generating the heatmap for City Hotel
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.heatmap(city_month_wise, cmap='YlGnBu', annot=True, fmt="d")
plt.title('Monthly Meal Count by City Hotel')
plt.xlabel('Hotel')
plt.ylabel('Month-Year')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# Generating the heatmap for Resort Hotel
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.heatmap(resort_month_wise, cmap='YlGnBu', annot=True, fmt="d")
plt.title('Monthly Meal Count by Resort Hotel')
plt.xlabel('Hotel')
plt.ylabel('Month-Year')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the number of bookings according to months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The maximum number of bookings for city hotel is during May 2017 with the numbers touching 4548. For resort hotel, the maximum number of booking is during October 2016 with numbers touching 1957.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Both the hotels should see the change in their booking numbers and focus of the factors that are refraining the guests from visiting in the other months of the year.

# %% [markdown]
# #### Chart 5: Bar Chart

# %% [markdown]
# Guest wise booking analysis

# %%
# Group by 'total_guest' and 'hotel' to get the count
guest_wise = hotel_booking_data.groupby(['total_guest', 'hotel']).size().reset_index(name='No. of booking')

# Calculate the percentage
total_bookings = guest_wise['No. of booking'].sum()
guest_wise['percentage'] = (guest_wise['No. of booking'] / total_bookings) * 100

# Separate data for City Hotel and Resort Hotel
city_hotel_data = guest_wise[guest_wise['hotel'] == 'City Hotel']
resort_hotel_data = guest_wise[guest_wise['hotel'] == 'Resort Hotel']
city_hotel_data
# Out:
#     total_guest       hotel  No. of booking  percentage
# 0             1  City Hotel           15567   13.111482
# 2             2  City Hotel           53917   45.412203
# 4             3  City Hotel            7705    6.489623
# 6             4  City Hotel            1860    1.566606
# 8             5  City Hotel              92    0.077488
# 11           10  City Hotel               1    0.000842
# 13           12  City Hotel               1    0.000842

# %%
resort_hotel_data
# Out:
#     total_guest         hotel  No. of booking  percentage
# 1             1  Resort Hotel            6722    5.661680
# 3             2  Resort Hotel           27963   23.552153
# 5             3  Resort Hotel            2774    2.336433
# 7             4  Resort Hotel            2066    1.740112
# 9             5  Resort Hotel              45    0.037902
# 10            6  Resort Hotel               1    0.000842
# 12           10  Resort Hotel               1    0.000842
# 14           12  Resort Hotel               1    0.000842
# 15           20  Resort Hotel               2    0.001685
# 16           26  Resort Hotel               5    0.004211
# 17           27  Resort Hotel               2    0.001685
# 18           40  Resort Hotel               1    0.000842
# 19           50  Resort Hotel               1    0.000842
# 20           55  Resort Hotel               1    0.000842

# %%
# Plot for City Hotel
plt.figure(figsize=(10, 5))
plt.bar(city_hotel_data['total_guest'], city_hotel_data['percentage'], color='blue')
plt.xlabel('Total Guests')
plt.ylabel('Percentage')
plt.title('City Hotel - Guest Wise Percentage')
plt.show()

# Plot for Resort Hotel
plt.figure(figsize=(10, 5))
plt.bar(resort_hotel_data['total_guest'], resort_hotel_data['percentage'], color='orange')
plt.xlabel('Total Guests')
plt.ylabel('Percentage')
plt.title('Resort Hotel - Guest Wise Percentage')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the type of guests that are visiting the hotels the most.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For city hotel the couples visit are 45.4% and for resort hotel the couples visit are 23%. The larger the number of guests the lesser is the percentage.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Both the hotels should focus on the fact that are not attracting groups. Keeping the right track of the factors they can enhance their KPIs in terms of group bookings.

# %% [markdown]
# #### Chart 6: Bar chart

# %% [markdown]
# Market Segment wise booking analysis

# %%
market_sagment_analysis=hotel_booking_data.groupby('market_segment')['hotel'].count().reset_index().sort_values(by='hotel',ascending=False)
market_sagment_analysis['percentage']=(market_sagment_analysis['hotel']/market_sagment_analysis['hotel'].sum())*100
market_sagment_analysis.rename(columns={'hotel':'No. of booking'},inplace=True)
market_sagment_analysis
# Out:
#   market_segment  No. of booking  percentage
# 6      Online TA           56333   47.447106
# 5  Offline TA/TO           24125   20.319554
# 4         Groups           19786   16.664982
# 3         Direct           12424   10.464254
# 2      Corporate            5099    4.294690
# 1  Complementary             726    0.611482
# 0       Aviation             235    0.197931

# %%
market_sagment_analysis.plot.bar(x='market_segment',y='percentage')
# Out:
# <Axes: xlabel='market_segment'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To observe the booking percentage for different market segment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The percentage of booking for online TA is highest which is 47.44% and its lowest for aviation which is 0.19%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# There is nothing as such.

# %% [markdown]
# #### Chart 7: Bar chart

# %% [markdown]
# Cancellation analysis

# %%
# Let's analyse the cancellation of booking for given dataset
Cancellation_analysis=hotel_booking_data.groupby('hotel')['is_canceled'].sum().reset_index()
Cancellation_analysis.rename(columns={'is_canceled':'No. of cancellation'},inplace=True)
Cancellation_analysis
# Out:
#           hotel  No. of cancellation
# 0    City Hotel                33061
# 1  Resort Hotel                11077

# %%
hotel_type_wise_booking_analysis
# Out:
#           hotel   meal
# 0    City Hotel  79143
# 1  Resort Hotel  39585

# %%
Cancellation=pd.merge(Cancellation_analysis, hotel_type_wise_booking_analysis, on='hotel', how='inner')
Cancellation['percentage']=(Cancellation['No. of cancellation']/Cancellation['meal'])*100 # here we used meal column just for count purpose
Cancellation.rename(columns={'meal': 'Total no. of bookings'}, inplace=True)
Cancellation
# Out:
#           hotel  No. of cancellation  Total no. of bookings  percentage
# 0    City Hotel                33061                  79143   41.773751
# 1  Resort Hotel                11077                  39585   27.982822

# %%
Cancellation.plot.bar(x='hotel',y='percentage')
# Out:
# <Axes: xlabel='hotel'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the cancellation rates of both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The cancellation rate for city hotel is 41.7% and for resort hotel it is 27.9%.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Both the hotels should analyse their KPIs to find the key factors that are triggering up the cancellation rates. This analysis brings an overall insight that can bring up additional strategies in their businesses to reduce these rates.

# %% [markdown]
# #### Chart 8: Scatter Plot

# %% [markdown]
# Occupancy rate

# %%
# Filter data for resort hotel and city hotel
resort_data = hotel_booking_data[hotel_booking_data['hotel'] == 'Resort Hotel']
city_data = hotel_booking_data[hotel_booking_data['hotel'] == 'City Hotel']

# Calculate occupancy rates for resort hotel and city hotel
resort_occupancy = (resort_data.groupby('Date')['is_canceled'].count() - resort_data.groupby('Date')['is_canceled'].sum()) / resort_data['reserved_room_type'].count() * 100
city_occupancy = (city_data.groupby('Date')['is_canceled'].count() - city_data.groupby('Date')['is_canceled'].sum()) / city_data['reserved_room_type'].count() * 100
# Plotting for Resort Hotel
plt.figure(figsize=(12, 6))
plt.scatter(resort_occupancy.index, resort_occupancy, label='Resort Hotel', color='blue', marker='o')
plt.title('Occupancy Rates over Time for Resort Hotel')
plt.xlabel('Date')
plt.ylabel('Occupancy Rate (%)')
plt.legend()
plt.grid(True)
plt.show()

# Plotting for City Hotel
plt.figure(figsize=(12, 6))
plt.scatter(city_occupancy.index, city_occupancy, label='City Hotel', color='red', marker='x')
plt.title('Occupancy Rates over Time for City Hotel')
plt.xlabel('Date')
plt.ylabel('Occupancy Rate (%)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the occupancy rates for both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The occupancy rates are maximum in between November to February for Resort Hotel. For City Hotels the maximum occupancy rates are during October and May.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Both the hotels can improve the occupancy rates by changing their business reforms. They should focus on increasing the rate for different time of the year as well to maintain a streamlined flow of guests and gradual improvement of business.

# %% [markdown]
# #### Chart 9: Count Plot

# %% [markdown]
# Preference analysis of families with babies and childrens.

# %%
# plotting for babies
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='babies',hue='hotel', data=hotel_booking_data, palette='viridis')
plt.title("Number of Babies in both hotels", size=15)
plt.xlabel('Babies')
plt.ylabel('Count')

# Plotting for children
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='children',hue='hotel', data=hotel_booking_data, palette='deep')
plt.title("Number of Children in both hotels", size=15)
plt.xlabel('Children')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the number of bookings numbers with babies and children

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Couples without babies and children are prefering city hotels with a count exceeding 70000. For resort hotels the count of couples without babies and children are in between 30000 to 40000. So resort hotels are prefered more for family destinations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Both the hotels should focus on their children anemities and parent's convenience to increase the count of family visits.

# %% [markdown]
# #### Chart 10: line plot

# %% [markdown]
# Revenue analysis

# %%
# Revenue analysis
plt.figure(figsize=(12, 6))
sns.lineplot(data=hotel_booking_data, x='arrival_date_month', y='adr', hue='hotel', estimator=np.sum)
plt.title('Revenue Analysis by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.legend(title='Hotel')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To observe the trends of revenue collected by the hotels with time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The revenue of both city hotel and resort hotel are highest during July and August. There is a drop of revenue and its the least in November and January. Then for city hotel it again spiked up in between May and June. For resort hotel there is a gradual rise in between May and June but it didn't spiked up.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Revenue depends on the pricing and other importent factors that drive the hotel business like bookings and customer engagement. So both the hotels should focus on increasing their revenue for the rest of the months of the year.

# %% [markdown]
# #### Chart 11: Bar chart

# %% [markdown]
# Car parking space analysis

# %%
# Calculate the value counts of required car parking spaces
parking_counts = hotel_booking_data['required_car_parking_spaces'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 8))
sns.barplot(x=parking_counts.index, y=parking_counts.values, palette='coolwarm')

# Set labels and title
plt.xlabel('Required Car Parking Spaces', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.title('Distribution of Required Car Parking Spaces', fontsize=15)

# Set the x-axis labels to be more readable
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# To show
plt.show()
# Out:
# <ipython-input-37-e6ba0699f68c>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=parking_counts.index, y=parking_counts.values, palette='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyse the parking space requirement for the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the guests donot need a parking space only a few need 1 space.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Both the hotels can reduce their car parking space and can enhance other annemities which can improve their customer engagement.

# %% [markdown]
# #### Chart 12: Heatmap

# %% [markdown]
# Repeated guest analysis

# %%
# Function to calculate the percentage of repeated guests
def calculate_repeated_guest_percentage(data):
    total_guests = data.groupby(['arrival_date_year', 'arrival_date_month']).size()
    repeated_guests = data[data['is_repeated_guest'] == 1].groupby(['arrival_date_year', 'arrival_date_month']).size()
    percentage_repeated_guests = (repeated_guests / total_guests * 100).unstack().fillna(0)
    return percentage_repeated_guests

# Filter the data
city_hotel_data = hotel_booking_data[hotel_booking_data['hotel'] == 'City Hotel']
resort_hotel_data = hotel_booking_data[hotel_booking_data['hotel'] == 'Resort Hotel']

# Calculate the percentage of repeated guests
city_percentage = calculate_repeated_guest_percentage(city_hotel_data)
resort_percentage = calculate_repeated_guest_percentage(resort_hotel_data)

# Create the heatmaps
plt.figure(figsize=(20, 9))

# Heatmap for City Hotel
plt.subplot(1, 2, 1)
sns.heatmap(city_percentage, cmap='Reds', annot=True, fmt=".2f")
plt.title('City Hotel Repeated Guest Percentage')
plt.xlabel('Month')
plt.ylabel('Year')

# Heatmap for Resort Hotel
plt.subplot(1, 2, 2)
sns.heatmap(resort_percentage, cmap='YlGnBu', annot=True, fmt=".2f")
plt.title('Resort Hotel Repeated Guest Percentage')
plt.xlabel('Month')
plt.ylabel('Year')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Why do you pick the specified chart?

# %% [markdown]
# To analyse the number of repeated guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotel has 7.31% of repeated guests for the month of July and resort hotel has 11.52% of repeated guests for the month of January (These are the highest values).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# As studied from the chart we can see that the number of repeated guests are less so the hotel needs to change the management strategies and look for the customer feedback that can help them improve their business and customer engagement.

# %% [markdown]
# #### Chart 13: Count plot

# %% [markdown]
# Customer type booking analysis

# %%
# Filter the data
city_hotel_data = hotel_booking_data[hotel_booking_data['hotel'] == 'City Hotel']
resort_hotel_data = hotel_booking_data[hotel_booking_data['hotel'] == 'Resort Hotel']

# Plotting for city hotel
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='customer_type', data= city_hotel_data, color= 'blue')
plt.title("Customer type wise booking (City hotel)", size=15)
plt.xlabel('Customer Type')
plt.ylabel('Count')

# Plotting for resort hotel data
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='customer_type', data= resort_hotel_data, color= 'yellow')
plt.title("Customer type wise booking (Resort hotel)", size=15)
plt.xlabel('Customer Type')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Solution to business objective

# %% [markdown]
# Solutions to the problems.
#
# Most of the hotels booked are city hotels, so it's essential to allocate the majority of our targeting funds towards these properties. We have also identified that the high rate of cancellations is likely due to our lenient no-deposit policies. To mitigate this, we should consider revising these policies. Additionally, our efforts should be concentrated on the months between May and August, as these are peak travel months due to the summer period.
#
# Our data indicates that the majority of our guests hail from Western Europe, suggesting that a significant portion of our advertising budget should be directed towards this region. Furthermore, the lack of repeat guests highlights the need to focus our advertising on strategies aimed at increasing guest retention and encouraging repeat visits. Implementing loyalty programs or offering special deals for returning guests could be effective in achieving this goal. By refining our targeting strategies, adjusting our deposit policies, and enhancing our focus on guest retention, we can optimize our marketing efforts and improve overall occupancy rates and guest satisfaction.

# %% [markdown]
# ## Project Conclusion

# %% [markdown]
# In conclusion, this EDA of hotel booking data has highlighted key booking trends, customer demographics, and factors influencing cancellations. The analysis showed a peak in bookings during summer months and holidays, with a significant proportion of reservations made through online travel agents. Most guests originate from Western Europe, with an average booking lead time of 45 days. Higher cancellation rates were associated with longer lead times and specific booking channels.
#
# To address these findings, it is recommended that the hotel management considers implementing stricter cancellation policies or offering incentives for non-refundable bookings. Additionally, marketing strategies should focus on attracting international guests during off-peak seasons to balance occupancy rates.
#
# While this analysis has provided valuable insights, future research could benefit from integrating customer satisfaction data to further refine understanding of guest behaviors. Overall, the insights gained from this EDA can help inform strategic decisions, optimize operations, and enhance the overall guest experience at the hotel.

# %% [markdown]
# ### Hurrah! You have successfully completed your EDA Capstone Project !!!
